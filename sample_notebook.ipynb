# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
pd.read_csv("0_id_name.csv")
# Out:
#       id             社名
# 0      0  (株) バンダイナムコＨＤ
# 1      1      (株)あおぞら銀行
# 2      2      (株)ふくおかＦＧ
# 3      3       (株)みずほＦＧ
# 4      4       (株)りそなＨＤ
# ..   ...            ...
# 220  220         ＮＴＮ(株)
# 221  221    ＳＯＭＰＯ ＨＤ(株)
# 222  222         ＴＤＫ(株)
# 223  223        ＴＯＴＯ(株)
# 224  224   Ｚホールディングス(株)
#
# [225 rows x 2 columns]

# %%
pd.read_csv("1_nikkei225_2015_2019.csv")
# Out:
#        id     年  月  17業種コード  33業種コード  規模コード       売上高  収益     経常利益      営業利益  \
# 0       0  2015  3       10     3800      2  565486.0 NaN  59383.0       NaN
# 1       0  2016  3       10     3800      2  575504.0 NaN  50774.0       NaN
# 2       0  2017  3       10     3800      2  620061.0 NaN  63290.0       NaN
# 3       0  2018  3       10     3800      2  678312.0 NaN  75380.0       NaN
# 4       0  2019  3       10     3800      2  732347.0 NaN  86863.0       NaN
# ...   ...   ... ..      ...      ...    ...       ...  ..      ...       ...
# 1058  224  2015  3       10     5250      4  428487.0 NaN      NaN  197212.0
# 1059  224  2016  3       10     5250      4  652327.0 NaN      NaN  224997.0
# 1060  224  2017  3       10     5250      4  853730.0 NaN      NaN  192049.0
# 1061  224  2018  3       10     5250      4  897185.0 NaN      NaN  185810.0
# 1062  224  2019  3       10     5250      4  954714.0 NaN      NaN  140528.0
#
# ...

# %%
pd.read_csv("2_keiei_tfidf.csv")
# Out:
#       id  keiei   risk  money  contract  reserch  svd_one_0  svd_one_1  \
# 0      0   8601   1865   7095      1025      599   0.372687  -0.019175
# 1      1   4528  18308  20844       171       11   0.335067  -0.183063
# 2      2   2738   6984  12571       547       11   0.334242  -0.220952
# 3      3   7222  11288  20585      3241        8   0.365277  -0.254450
# 4      4   3574   9027  21292        12       11   0.318343  -0.261082
# ..   ...    ...    ...    ...       ...      ...        ...        ...
# 220  220   6479   3195   7931       195     1618   0.592686   0.242717
# 221  221   2861   5076  17279      2986       11   0.548903  -0.215022
# 222  222   2046   7300  10300       323     1758   0.419721   0.002170
# 223  223   8879   5476   5435       113     2261   0.578310   0.457016
# 224  224   1296  39722   3863      1523       49   0.353809  -0.052608
#
#      svd_one_2  svd_one_3  svd_one_4  svd_one_5  svd_one_6  svd_one_7  \
# ...

# %%
pd.read_csv("3_emotion_score.csv")
# Out:
#       id  keiei-pos  keiei-neu  keiei-neg  risk-pos  risk-neu  risk-neg  \
# 0      0       0.05       0.94       0.01      0.05      0.94      0.01
# 1      1       0.03       0.96       0.01      0.03      0.97      0.00
# 2      2       0.05       0.91       0.04      0.05      0.94      0.01
# 3      3       0.02       0.97       0.01      0.06      0.93      0.01
# 4      4       0.02       0.97       0.01      0.05      0.94      0.01
# ..   ...        ...        ...        ...       ...       ...       ...
# 220  220       0.03       0.96       0.01      0.05      0.94      0.01
# 221  221       0.04       0.96       0.00      0.03      0.97      0.00
# 222  222       0.03       0.97       0.00      0.03      0.97      0.00
# 223  223       0.09       0.90       0.01      0.05      0.93      0.02
# 224  224       0.09       0.88       0.03      0.08      0.90      0.02
#
#      money-pos  money-neu  money-neg  contract-pos  contract-neu  \
# ...

# %%
pd.read_csv("4_description_2018.csv")
# Out:
#       id                                                  0  \
# 0      0  文中の将来に関する事項は、当連結会計年度末現在において当社グループが判断したものであります。...
# 1      1  文中における財務数値の記載金額は、億円単位未満は四捨五入して表示しております。なお、財務目標...
# 2      2  文中の将来に関する事項は、当連結会計年度末現在において、当社グループが判断したものであります...
# 3      3  文中の将来に関する事項は、当連結会計年度末現在において当社グループが判断したものであります。...
# 4      4  りそなグループの経営方針、経営環境及び対処すべき課題等は以下のとおりであります。なお、記載事...
# ..   ...                                                ...
# 220  220  (1）会社の経営の基本方針当社グループは「新しい技術の創造と新商品の開発を通じて国際社会に貢...
# 221  221  当社グループの経営方針、経営環境、経営戦略および対処すべき課題は以下のとおりであります。なお...
# 222  222  ①当社グループの経営の基本方針当社は、世界初の磁性材料フェライトの工業化を目的として1935...
# 223  223  （1）会社の経営の基本方針当社グループは、社是「愛業至誠：良品と均質奉仕と信用協力と発展」と...
# 224  224  １. 経営の基本方針当社グループは、情報技術の力で日本の課題を解決する「課題解決エンジン」を...
#
#                                                      1  \
# 0    有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 1    文中における将来に関する事項は、有価証券報告書提出日現在において当行及び当行グループが判断し...
# 2    当社及び当社グループの事業その他に関するリスクについて、投資者の判断に重要な影響を及ぼす可能...
# ...

# %%
pd.read_csv("5_description_2019.csv")
# Out:
#       id                                                  0  \
# 0      0  文中の将来に関する事項は、当連結会計年度末現在において当社グループが判断したものであります。...
# 1      1  文中の将来に関する事項は、当連結会計年度末現在において当行が判断したものであります。（１）ビ...
# 2      2  文中の将来に関する事項は、当連結会計年度末現在において、当社グループが判断したものであります...
# 3      3  文中の将来に関する事項は、当連結会計年度末現在において当社グループが判断したものであります。...
# 4      4  当グループの経営方針、経営環境及び対処すべき課題等は以下のとおりであります。なお、記載事項の...
# ..   ...                                                ...
# 220  220  (1）会社の経営の基本方針当社グループは「新しい技術の創造と新商品の開発を通じて国際社会に貢...
# 221  221  当社グループの経営方針、経営環境、経営戦略および対処すべき課題等は以下のとおりであります。な...
# 222  222  文中の将来に関する事項は、当連結会計年度末現在において当社グループが判断したものであります。...
# 223  223  （1）会社の経営の基本方針当社グループは、社是「愛業至誠：良品と均質 奉仕と信用 協力と発展...
# 224  224  １. 経営の基本方針当社グループは、情報技術の力で日本の課題を解決する「課題解決エンジン」を...
#
#                                                      1  \
# 0    有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 1    文中における将来に関する事項は、有価証券報告書提出日現在において当行及び当行グループが判断し...
# 2    当社及び当社グループの事業その他に関するリスクについて、投資者の判断に重要な影響を及ぼす可能...
# ...
